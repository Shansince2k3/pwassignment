# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# ### Ans
# #### Matplotlib is a popular data visualization library in Python that provides a wide range of tools for creating static, animated, and interactive visualizations.
# #### It is widely used in various fields such as data analysis, scientific research, engineering, and more.
# #### - It offers a flexible and customizable interface for creating a wide variety of plots, from simple line plots to complex 3D visualizations.
# #### Here are five types of plots that can be created using the Pyplot module of Matplotlib:
#
# 1. Line Plot: Line plots are created using the plot() function and are used to visualize the relationship between two continuous variables over a continuous interval.
# 2. Scatter Plot: Scatter plots are created using the scatter() function and are used to display the relationship between two continuous variables as individual data points.
# 3. Bar Plot: Bar plots are created using the bar() or barh() function and are used to compare discrete categories or groups by representing them as bars of varying heights or lengths.
# 4. Histogram: Histograms are created using the hist() function and are used to visualize the distribution of a continuous variable by dividing the data into bins and showing the frequency or count of data points in each bin.
# 5. Pie Chart: Pie charts are created using the pie() function and are used to display the composition of categorical data as slices of a pie, where each slice represents a category and its proportion.

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %% [markdown]
# #### Ans - A scatter plot is a type of data visualization that displays the relationship between two numerical variables. It uses dots or markers on a two-dimensional coordinate system, with each dot representing a single data point.

# %%
import numpy as np
import matplotlib.pyplot as plt

# np.random.rand() function from NumPy to generate random values between 0 and 1 for both x and y variables. 
np.random.seed(0)
x = np.random.rand(20)  # Random x-values between 0 and 1
y = np.random.rand(20)  # Random y-values between 0 and 1

colours = np.random.rand(20) #dot sare alg color mein dot ho
sizes = 650*np.random.rand(20)

plt.scatter(x,y,c = colours,s =sizes,alpha = 1) 
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot')
plt.show()

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
#Note: Also add title, xlabel, and ylabel to the plot.

plt.scatter(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# ### Use the following data:
# ### import numpy as np
# #### For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# #### For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# #### For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# #### For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
import numpy as np
import matplotlib.pyplot as plt


x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create a 2x2 grid of subplots
# plt.subplot(2, 2, 1)

# %%
fig, axs = plt.subplots(1, 4, figsize=(12, 3))
# Plot line 1
axs[0].plot(x1, y1)
axs[0].set_title('Line 1')
# Plot line 2
axs[1].plot(x2, y2)
axs[1].set_title('Line 2')
# Plot line 3
axs[2].plot(x3, y3)
axs[2].set_title('Line 3')
# Plot line 4
axs[3].plot(x4, y4)
axs[3].set_title('Line 4')

# Adjust spacing between subplots
plt.tight_layout()
# Display the plot
plt.show()

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# #### import numpy as np
# #### company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# #### profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# ### Ans - A bar plot is a type of data visualization that represents categorical data with rectangular bars. It displays the relationship between a categorical variable and a numerical variable.
# ### Bar plots are commonly used to compare and visualize the values of different categories, such as comparing the sales of different products or the performance of different companies.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.figure(figsize=(5, 3))
plt.bar(company,profit)
plt.xlabel('Company')
plt.ylabel('Profit')
plt.title('Company Profits')
plt.show()

# %%
plt.figure(figsize=(5, 3))
plt.barh(company, profit)
plt.xlabel('Company')
plt.ylabel('Profit')
plt.title('Company Profits')
plt.show()

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# #### box1 = np.random.normal(100, 10, 200)
# #### box2 = np.random.normal(90, 20, 200)

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)


data = [box1, box2]
labels = ['Box 1', 'Box 2']

plt.boxplot(data, labels=labels)

plt.xlabel('Box')
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

# %% [markdown]
# #### Ans A box plot is a type of plot that displays the distribution of a dataset along with its outliers. The plot is based on a five-number summary of the data, which includes the minimum value, the first quartile (25th percentile), the median (50th percentile), the third quartile (75th percentile), and the maximum value. The box in the plot spans the first quartile to the third quartile, and the median is shown as a horizontal line within the box. The whiskers extend from the box to the minimum and maximum values, but may be extended further to show the presence of outliers.
#
# #### Box plots are commonly used to visualize the distribution of a dataset and identify potential outliers. They are particularly useful when comparing multiple datasets or groups. Box plots can help to identify differences in the distribution, such as differences in the spread or the presence of outliers, between groups.
